# %%
#Loading in required libraries for code

from math import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn import linear_model
from sklearn.metrics import recall_score, precision_score, classification_report,accuracy_score,confusion_matrix, roc_curve, auc, roc_curve,accuracy_score,plot_confusion_matrix
from sklearn.preprocessing import StandardScaler, normalize
from scipy import ndimage
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import LogisticRegression
import seaborn as sns
sns.set_theme()
sns.set_context("poster")

# %%
#Loading in the train and testing data sets from kaggle

test_data = pd.read_csv('../exoTest.csv')
train_data = pd.read_csv('../exoTrain.csv')

# %%
#The Labels are 2 for exoplanet and 1 for non exoplanet so we have to switch them to 2->1 and 1->0

new_labels_test = []
for i in test_data['LABEL']:
    if i == 2:
        new_labels_test.append(1)
        
    if i == 1:
        new_labels_test.append(0)

test_data = test_data.drop(columns= ['LABEL'])
test_data.insert(0, 'NEW_LABEL', new_labels_test)

# %%
#For both datasets

new_labels_train = []
for i in train_data['LABEL']:
    if i == 2:
        new_labels_train.append(1)
        
    if i == 1:
        new_labels_train.append(0)

train_data = train_data.drop(columns= ['LABEL'])
train_data.insert(0, 'NEW_LABEL', new_labels_train)

# %%
#Remove outliers, shown by scatter plot; removed by IQR or another method
# train_data.drop(train_data[train_data['FLUX.1']>250000].index, axis=0, inplace=True)

# %%
train_data
# Out:
#       NEW_LABEL   FLUX.1   FLUX.2   FLUX.3   FLUX.4   FLUX.5   FLUX.6  FLUX.7  \
# 0             1    93.85    83.81    20.10   -26.98   -39.56  -124.71 -135.18
# 1             1   -38.88   -33.83   -58.54   -40.09   -79.31   -72.81  -86.55
# 2             1   532.64   535.92   513.73   496.92   456.45   466.00  464.50
# 3             1   326.52   347.39   302.35   298.13   317.74   312.70  322.33
# 4             1 -1107.21 -1112.59 -1118.95 -1095.10 -1057.55 -1034.48 -998.34
# ...         ...      ...      ...      ...      ...      ...      ...     ...
# 5082          0   -91.91   -92.97   -78.76   -97.33   -68.00   -68.24  -75.48
# 5083          0   989.75   891.01   908.53   851.83   755.11   615.78  595.77
# 5084          0   273.39   278.00   261.73   236.99   280.73   264.90  252.92
# 5085          0     3.82     2.09    -3.29    -2.88     1.66    -0.75    3.85
# 5086          0   323.28   306.36   293.16   287.67   249.89   218.30  188.86
#
#        FLUX.8  FLUX.9  ...  FLUX.3188  FLUX.3189  FLUX.3190  FLUX.3191  \
# 0      -96.27  -79.89  ...     -78.07    -102.15    -102.15      25.13
# 1      -85.33  -83.97  ...      -3.28     -32.21     -32.21     -24.89
# 2      486.39  436.56  ...     -71.69      13.31      13.31     -29.89
# 3      311.31  312.42  ...       5.71      -3.73      -3.73      30.05
# 4    -1022.71 -989.57  ...    -594.37    -401.66    -401.66    -357.24
# ...       ...     ...  ...        ...        ...        ...        ...
# 5082   -49.25  -30.92  ...     139.95     147.26     156.95     155.64
# 5083   458.87  492.84  ...     -26.50      -4.84     -76.30     -37.84
# 5084   254.88  237.60  ...     -26.82     -53.89     -48.71      30.99
# 5085    -0.03    3.28  ...      10.86      -3.23      -5.10      -4.61
# 5086   178.93  118.93  ...      71.19       0.97      55.20      -1.63
#
#       FLUX.3192  FLUX.3193  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# 0         48.57      92.54      39.32      61.42       5.08     -39.54
# 1         -4.86       0.76     -11.70       6.46      16.00      19.93
# 2        -20.88       5.06     -11.80     -28.91     -70.02     -96.67
# 3         20.03     -12.67      -8.77     -17.31     -17.35      13.98
# 4       -443.76    -438.54    -399.71    -384.65    -411.79    -510.54
# ...         ...        ...        ...        ...        ...        ...
# 5082     156.36     151.75     -24.45     -17.00       3.23      19.28
# 5083    -153.83    -136.16      38.03     100.28     -45.64      35.58
# 5084      15.96      -3.47      65.73      88.42      79.07      79.43
# 5085      -9.82      -1.50      -4.65     -14.55      -6.41      -2.55
# 5086      -5.50     -25.33     -41.31     -16.72     -14.09      27.82
#
# [5087 rows x 3198 columns]

# %%
#Observing the intensity of flux values from training data of exoplanets vs non exoplanets 5 of each

plt.figure(figsize = (15,8))
plt.title('Flux intensities of Exoplanet stars', size = 20)

#Exoplanet ones
plt.plot(train_data.iloc[0,1:], color = 'blue')
plt.plot(train_data.iloc[1,1:], color = 'red')
plt.plot(train_data.iloc[5,1:], color = 'orange')

plt.xlabel('Flux values', size = 20)
plt.ylabel('Flux intensities', size = 20)
plt.xticks(rotation = 45, ticks = np.arange(0,3197,150), size = 10)

plt.show()

# %%
plt.figure(figsize = (15,8))
plt.title('Flux intensities of non-Exoplanet stars', size=20)

plt.plot(train_data.iloc[211,1:], color = 'blue')
plt.plot(train_data.iloc[400,1:], color = 'orange')
plt.plot(train_data.iloc[500,1:], color = 'red')

plt.xlabel('Flux values', size = 20)
plt.ylabel('Flux intensities', size = 20)
plt.xticks(rotation = 45, ticks = np.arange(0,3197,150), size = 10)
plt.show()

# %%
train_data.drop(train_data[train_data['FLUX.1']>250000].index, axis=0, inplace=True)

# %% [markdown]
# ## Setting up train/test split for machine learning

# %%
#Splitting the data into labels and features for both training and testing sets

train_fluxes = train_data.drop(columns = ['NEW_LABEL'],axis=1)

train_labels = train_data['NEW_LABEL']

test_fluxes = test_data.drop(columns = ['NEW_LABEL'],axis=1)

test_labels = test_data['NEW_LABEL']

# %%
train_fluxes = normalized = normalize(train_fluxes)
test_fluxes = normalize(test_fluxes)

# %%
#Applying Guassian Filter

train_fluxes = ndimage.filters.gaussian_filter(train_fluxes, sigma = 10)

test_fluxes = ndimage.filters.gaussian_filter(test_fluxes, sigma = 10)

# %%
#Feature Scaling

std_scaler = StandardScaler()
train_fluxes = scaled = std_scaler.fit_transform(train_fluxes)
test_fluxes = std_scaler.fit_transform(test_fluxes)

# %% [markdown]
# # Apply Various Methods

# %% [markdown]
# ## K Closest Neighbors

# %%
#K closest neighbors
knn_model = KNeighborsClassifier()
results = knn_model.fit(train_fluxes,train_labels)

prediction = results.predict(test_fluxes)

print(f"Score: {results.score(test_fluxes,test_labels)}%\n")

fig, axs = plt.subplots(figsize = (16,7))
sns.heatmap(confusion_matrix(test_labels,prediction), cmap = "viridis", annot = True,fmt = "d",
            annot_kws = {'size':15},linewidths=3,linecolor="black", ax = axs)
axs.set_title("Confusion Matrix", size = 20)
# Out:
# Score: 0.9912280701754386%
# Text(0.5, 1.0, 'Confusion Matrix')

# %% [markdown]
# ## Perception

# %%
model = Perceptron()
results = model.fit(train_fluxes, train_labels)

pred = results.predict(test_fluxes)
print(f"The Accuracy of Logistic Regession is {accuracy_score(pred,test_labels)}")

fig, axs = plt.subplots(figsize = (16,7))
sns.heatmap(confusion_matrix(test_labels,pred), cmap = "viridis", annot = True,fmt = "d",
            annot_kws = {'size':15},linewidths=3,linecolor="black", ax = axs)
axs.set_title("Confusion Matrix", size = 20)
# Out:
# The Accuracy of Logistic Regession is 0.9070175438596492
# Text(0.5, 1.0, 'Confusion Matrix')

# %% [markdown]
# ## Logistic

# %%
model = LogisticRegression(class_weight={0:100, 1:1})
model.fit(train_fluxes,train_labels)

pred = model.predict(test_fluxes)
print(f"The Accuracy of Logistic Regession is {accuracy_score(pred,test_labels)}")

fig, axs = plt.subplots(figsize = (16,7))
sns.heatmap(confusion_matrix(test_labels,pred), cmap = "viridis", annot = True,fmt = "d",
            annot_kws = {'size':15},linewidths=3,linecolor="black", ax = axs)
axs.set_title("Confusion Matrix", size = 20)
# Out:
# The Accuracy of Logistic Regession is 0.9842105263157894
# /home/shield94/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Text(0.5, 1.0, 'Confusion Matrix')

# %% [markdown]
# # Using SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
model = SMOTE()

ov_train_x,ov_train_y = model.fit_resample(train_data.drop('NEW_LABEL',axis=1), train_data['NEW_LABEL'])
ov_train_y = ov_train_y.astype('int')

# %%
plt.figure(figsize =(15,7))
sns.barplot(y = ov_train_y.value_counts(), x = [0,1])
# Out:
# <AxesSubplot:ylabel='NEW_LABEL'>

# %%
train_fluxes, test_fluxes, train_labels, test_labels = train_test_split(ov_train_x, ov_train_y, test_size=0.25, random_state=42)

# %%
#K closest neighbors
knn_model = KNeighborsClassifier()
results = knn_model.fit(train_fluxes,train_labels)

prediction = results.predict(test_fluxes)

print(f"Score: {results.score(test_fluxes,test_labels)}%\n")

fig, axs = plt.subplots(figsize = (16,7))
sns.heatmap(confusion_matrix(test_labels,prediction), cmap = "viridis", annot = True,fmt = "d",
            annot_kws = {'size':15},linewidths=3,linecolor="black", ax = axs)
axs.set_title("Confusion Matrix", size = 20)
# Out:
# Score: 0.9821782178217822%
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
model = Perceptron()
results = model.fit(train_fluxes, train_labels)

pred = results.predict(test_fluxes)
print(f"Score: {results.score(test_fluxes,test_labels)}%\n")

fig, axs = plt.subplots(figsize = (16,7))
sns.heatmap(confusion_matrix(test_labels,pred), cmap = "viridis", annot = True,fmt = "d",
            annot_kws = {'size':15},linewidths=3,linecolor="black", ax = axs)
axs.set_title("Confusion Matrix", size = 20)
# Out:
# Score: 0.7548514851485149%
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
model = LogisticRegression(class_weight={0:100, 1:1})
model.fit(train_fluxes,train_labels)

pred = model.predict(test_fluxes)
print(f"The Accuracy of Logistic Regession is {accuracy_score(pred,test_labels)}")

fig, axs = plt.subplots(figsize = (16,7))
sns.heatmap(confusion_matrix(test_labels,pred), cmap = "viridis", annot = True,fmt = "d",
            annot_kws = {'size':15},linewidths=3,linecolor="black", ax = axs)
axs.set_title("Confusion Matrix", size = 20)
# Out:
# The Accuracy of Logistic Regession is 0.6962376237623762
# /home/shield94/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Text(0.5, 1.0, 'Confusion Matrix')
